# %% [markdown]
# <a href="https://colab.research.google.com/github/akshatgattani4/AI-ML/blob/main/Employee_Attrition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Import the Libraries.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ###Importing the dataset.

# %%
data = pd.read_csv("Employee-Attrition.csv")

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.shape
# Out:
# (1470, 35)

# %% [markdown]
# ###Checking for Null Values.

# %%
data.isnull().any()
# Out:
# Age                         False
# Attrition                   False
# BusinessTravel              False
# DailyRate                   False
# Department                  False
# DistanceFromHome            False
# Education                   False
# EducationField              False
# EmployeeCount               False
# EmployeeNumber              False
# EnvironmentSatisfaction     False
# Gender                      False
# HourlyRate                  False
# JobInvolvement              False
# JobLevel                    False
# JobRole                     False
# JobSatisfaction             False
# MaritalStatus               False
# MonthlyIncome               False
# MonthlyRate                 False
# NumCompaniesWorked          False
# Over18                      False
# OverTime                    False
# PercentSalaryHike           False
# PerformanceRating           False
# RelationshipSatisfaction    False
# StandardHours               False
# ...

# %% [markdown]
# ###Data Visualization.

# %%
data.corr()
# Out:
# <ipython-input-120-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# ...

# %%
data.Attrition.value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
plt.pie(data.Attrition.value_counts(), labels = ['No', 'Yes'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7a98d20832b0>,
# ...
#  [Text(-0.9618916732177651, 0.5336332157899547, 'No'),
#   Text(0.961891673217765, -0.5336332157899548, 'Yes')])

# %%
data.Department.value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
df = data.groupby(['Department', 'Attrition']).size()
df = df.unstack()
df.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Department'>

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df = data.groupby(['BusinessTravel', 'Attrition']).size()
df = df.unstack()
df.plot(kind = 'bar')
# Out:
# <Axes: xlabel='BusinessTravel'>

# %% [markdown]
# ###Outlier Detection

# %%
sns.boxplot(data.DailyRate)
# Out:
# <Axes: >

# %%
sns.boxplot(data.DistanceFromHome)
# Out:
# <Axes: >

# %%
sns.boxplot(data.TotalWorkingYears)
# Out:
# <Axes: >

# %%
q1 = data.TotalWorkingYears.quantile(0.25)
q3 = data.TotalWorkingYears.quantile(0.75)
IQR = q3-q1
upper_limit = q3+1.5*IQR

# %%
data = data[data.TotalWorkingYears < upper_limit]

# %%
sns.boxplot(data.TotalWorkingYears)
# Out:
# <Axes: >

# %% [markdown]
# ###Perform Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
data.Attrition = le.fit_transform(data.Attrition)
data.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1407 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1407 non-null   int64
#  1   Attrition                 1407 non-null   int64
#  2   BusinessTravel            1407 non-null   object
#  3   DailyRate                 1407 non-null   int64
#  4   Department                1407 non-null   object
#  5   DistanceFromHome          1407 non-null   int64
#  6   Education                 1407 non-null   int64
#  7   EducationField            1407 non-null   object
#  8   EmployeeCount             1407 non-null   int64
#  9   EmployeeNumber            1407 non-null   int64
#  10  EnvironmentSatisfaction   1407 non-null   int64
#  11  Gender                    1407 non-null   object
#  12  HourlyRate                1407 non-null   int64
#  13  JobInvolvement            1407 non-null   int64
# ...

# %%
data.BusinessTravel = le.fit_transform(data.BusinessTravel)
data.Department = le.fit_transform(data.Department)
data.Gender = le.fit_transform(data.Gender)
data.JobRole = le.fit_transform(data.JobRole)

# %%
sns.barplot(x = 'Gender', y='Attrition', data = data, errorbar =None)
# Out:
# <Axes: xlabel='Gender', ylabel='Attrition'>

# %%
sns.barplot(x = 'Department', y='Attrition', data = data, errorbar =None)
# Out:
# <Axes: xlabel='Department', ylabel='Attrition'>

# %%
plt.subplots(figsize = (20,10))
sns.heatmap(data.corr())
# Out:
# <ipython-input-139-c3473a6271fc>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr())
# <Axes: >

# %%
data = data.drop(['Age', 'YearsInCurrentRole', 'YearsAtCompany', 'StockOptionLevel', 'TotalWorkingYears', 'JobLevel', 'EmployeeCount','StandardHours' ,'EmployeeNumber'], axis = 1)

# %%
data.head()
# Out:
#    Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0          1               2       1102           2                 1
# 1          0               1        279           1                 8
# 2          1               2       1373           1                 2
# 3          0               1       1392           1                 3
# 4          0               2        591           1                 2
#
#    Education EducationField  EnvironmentSatisfaction  Gender  HourlyRate  ...  \
# 0          2  Life Sciences                        2       0          94  ...
# 1          1  Life Sciences                        3       1          61  ...
# 2          2          Other                        4       1          92  ...
# 3          4  Life Sciences                        4       0          56  ...
# 4          1        Medical                        1       1          40  ...
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1407 entries, 0 to 1469
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition                 1407 non-null   int64
#  1   BusinessTravel            1407 non-null   int64
#  2   DailyRate                 1407 non-null   int64
#  3   Department                1407 non-null   int64
#  4   DistanceFromHome          1407 non-null   int64
#  5   Education                 1407 non-null   int64
#  6   EducationField            1407 non-null   object
#  7   EnvironmentSatisfaction   1407 non-null   int64
#  8   Gender                    1407 non-null   int64
#  9   HourlyRate                1407 non-null   int64
#  10  JobInvolvement            1407 non-null   int64
#  11  JobRole                   1407 non-null   int64
#  12  JobSatisfaction           1407 non-null   int64
#  13  MaritalStatus             1407 non-null   object
# ...

# %%
for col in ['EducationField','Over18','OverTime','MaritalStatus']:
    data[col] = le.fit_transform(data[col])

# %%
data.head()
# Out:
#    Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0          1               2       1102           2                 1
# 1          0               1        279           1                 8
# 2          1               2       1373           1                 2
# 3          0               1       1392           1                 3
# 4          0               2        591           1                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0          2               1                        2       0          94
# 1          1               1                        3       1          61
# 2          2               4                        4       1          92
# 3          4               1                        4       0          56
# 4          1               3                        1       1          40
#
#    ...  NumCompaniesWorked  Over18  OverTime  PercentSalaryHike  \
# ...

# %% [markdown]
# ###Splitting Dependent and Independent variables

# %%
x = data.drop(['Attrition'], axis = 1)
y = data['Attrition']

# %% [markdown]
# ###Feature Scaling.

# %%
from sklearn.preprocessing import MinMaxScaler
ms = MinMaxScaler()

# %%
x_scaled = pd.DataFrame(ms.fit_transform(x))

# %% [markdown]
# ###Splitting Data into Train and Test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scaled,y,test_size = 0.2, random_state = 0)

# %% [markdown]
# ###Model Building using Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lgr = LogisticRegression()

# %%
lgr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lgr.predict(x_test)
pred = pd.DataFrame({"Actual" : y_test, "Predicted" : y_pred})
pred
# Out:
#       Actual  Predicted
# 1288       0          0
# 326        0          0
# 232        0          0
# 636        1          0
# 1296       0          0
# ...      ...        ...
# 1110       1          0
# 964        0          0
# 1066       0          0
# 314        0          0
# 480        1          0
#
# [282 rows x 2 columns]

# %% [markdown]
# ###Calculate Performance metrics for Logistic Regression

# %%
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix, accuracy_score, classification_report

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8723404255319149

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[231,   1],
#        [ 35,  15]])

# %%
from sklearn import metrics

# %%
metrics.r2_score(y_test, y_pred)
# Out:
# 0.12482758620689649

# %%
prob = lgr.predict_proba(x_test)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, prob)
plt.plot(fpr, tpr)

# %% [markdown]
# ###Model Building using Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=10, criterion = 'entropy', random_state=0)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %% [markdown]
# ###Calculate Performance metrics for Random Forest

# %%
rf.score(x_train,y_train)
# Out:
# 0.9795555555555555

# %%
y_pred = rf.predict(x_test)
pred = pd.DataFrame({"Actual" : y_test, "Predicted" : y_pred})
pred
# Out:
#       Actual  Predicted
# 1288       0          0
# 326        0          0
# 232        0          0
# 636        1          0
# 1296       0          0
# ...      ...        ...
# 1110       1          0
# 964        0          0
# 1066       0          0
# 314        0          0
# 480        1          0
#
# [282 rows x 2 columns]

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8368794326241135

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[232,   0],
#        [ 46,   4]])

# %%
metrics.r2_score(y_test, y_pred)
# Out:
# -0.11827586206896568

# %% [markdown]
# ###Model Building using Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()

# %%
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.score(x_train,y_train)
# Out:
# 1.0

# %%
y_pred = dt.predict(x_test)
pred = pd.DataFrame({"Actual" : y_test, "Predicted" : y_pred})
pred
# Out:
#       Actual  Predicted
# 1288       0          0
# 326        0          0
# 232        0          1
# 636        1          0
# 1296       0          0
# ...      ...        ...
# 1110       1          0
# 964        0          0
# 1066       0          0
# 314        0          0
# 480        1          0
#
# [282 rows x 2 columns]

# %% [markdown]
# ###Calculate Performance metrics for Decision Tree

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.776595744680851

# %%
metrics.r2_score(y_test, y_pred)
# Out:
# -0.5315517241379311

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[205,  27],
#        [ 36,  14]])
